# %% [markdown]
# # Finding the Main Factors Affecting Teen Pregnancy
# This project looks at various socio-economic and political data to find factors that strongly correlate with increases in teen pregnancy rate. I aggregated, cleaned, and analyzed data factors related to:
# - religion
# - education
# - politics
# - state GDP
# - population density
# - public school funding
# - poverty rate and median income
# - abortion rates for teens and overall
# - sexual education approaches
# - race
#
# ### Key Questions Explored:
# - Which of the studied variables significantly correlate with teen pregnancy rate?
# - Which factor(s) most strongly affects teen pregnancy rate?
#
# ### Techniques used:
# - pandas for data cleaning
# - matplotlib for data visualization
# - scikitlearn for linear regression (with regularization)
# - statsmodel for summary statistics
# - plotly for interactive maps (see end)
#
# ### Key Findings:
# - Religiosity and poverty rate in each state appears to have the strongest effect on teen pregnancy rate, followed by population density. No other studied factors had a significant effect
#
# ### Data Sources:
# - Teen Pregnancy rates: https://www.hhs.gov/ash/oah/adolescent-development/reproductive-health-and-teen-pregnancy/teen-pregnancy-and-childbearing/trends/index.html
# - Religiosity by state: http://www.pewforum.org/religious-landscape-study/state/california/#importance-of-religion-by-state
# - GDP by state: https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP#cite_note-2
# - Election results: https://en.wikipedia.org/wiki/United_States_presidential_election
# - Population, Land area: http://www.ipl.org/div/stateknow/popchart.html
# - Public education spending: http://www.governing.com/gov-data/education-data/state-education-spending-per-pupil-data.html
# - Poverty rate: https://en.wikipedia.org/wiki/List_of_U.S._states_by_poverty_rate
# - Median income by state: https://en.wikipedia.org/wiki/List_of_U.S._states_by_income
# - Abortion rate by state: http://www.kff.org/womens-health-policy/state-indicator/abortion-rate/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D
# - Abortion percentage by age: http://www.kff.org/womens-health-policy/state-indicator/distribution-of-abortions-by-age/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D
# - Sex Education by state: https://www.guttmacher.org/state-policy/explore/sex-and-hiv-education
# - Population breakdown by race: http://www.kff.org/other/state-indicator/distribution-by-raceethnicity/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D

# %% [markdown]
# # Reading and understanding dataset
# The data from the sources list above were compiled into a single .csv file. The major factors to be studied are listed after the next cell. A brief rundown of non-descriptive columns:
# - Rel-... = survey results for importance of religion
# - Edu-... = percent of state residents with certain education level
# - 2010 to 2014 change / 2014 spend per student = state funding for public education
# - White/Black/Hispanic/Asian = breakdown of state population by race

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('teen pregnancy rate v3.csv')

data=data[0:51]
data.iloc[0]
# Out:
# State                                       Alabama
# Code                                             AL
# Teen birth rate (15-19 year olds)                32
# Rel-Very Important                              77%
# Rel-Somewhat Important                          13%
# Rel-Not too important                            6%
# Rel-Not at all important                         4%
# Rel-Sample Size                                 511
# Edu-High School                              84.30%
# Edu-Bachelors                                23.50%
# Edu-Advanced                                  8.70%
# Clinton vote %                               34.36%
# Trump vote %                                 62.08%
# Gary Johnson vote %                           2.09%
# Jill Stein vote %                             0.44%
# Obama vote %-12                              38.36%
# Romney vote %-12                             60.55%
# Gary Johnson vote %-12                        0.59%
# Jill Stein vote %-12                          0.16%
# Obama vote % 08                              38.74%
# McCain vote %                                60.32%
# GDP (millions)                              204,861
# Population                                4,779,736
# Land Area (sq mi)                         50,744.00
# 2010 to 2014 change                          -6.40%
# 2014 spent per student                       $9,028
# Poverty Rate                                 19.20%
# Median Income                               $44,765
# abortion per 1000 women (aged 15-44)              9
# fraction of abortions under age 19             0.13
# sex ed mandated                                 NaN
# HIV ed mandated                                   X
# must be medically accurate                      NaN
# must be age appropriate                           X
# must be unbiased                                NaN
# cannot promote religion                         NaN
# must discuss contraception                        X
# importance of abstinence                     stress
# Importance of Sex Only Within Marriage            X
# Discuss Sexual Orientation                 negative
# Negative Outcomes of Teen Sex                     X
# Family Communication                            NaN
# White                                          0.65
# Black                                          0.27
# Hispanic                                       0.04
# Asian                                          0.04
# Name: 0, dtype: object

# %% [markdown]
# # Data Cleaning
# 'X' values mean the state does follow the respective guideline, while 'NaN' cells mean states do not follow the guideline. Cells with 'na' show data was not available. 'stress' and 'cover' indicate how much schools emphasize a respective topic.

# %%
data.loc[:5,'abortion per 1000 women (aged 15-44)':'Family Communication']
# Out:
#    abortion per 1000 women (aged 15-44)  fraction of abortions under age 19  \
# 0                                     9                                0.13
# 1                                    10                                0.14
# 2                                    10                                0.11
# 3                                    10                                0.12
# 4                                    10                                0.12
# 5                                    10                                0.12
#
#   sex ed mandated HIV ed mandated must be medically accurate  \
# 0             NaN               X                        NaN
# 1              na              na                         na
# 2             NaN             NaN                        NaN
# 3             NaN             NaN                        NaN
# 4               X               X                          X
# 5             NaN             NaN                          X
#
#   must be age appropriate must be unbiased cannot promote religion  \
# 0                       X              NaN                     NaN
# 1                      na               na                      na
# 2                       X              NaN                     NaN
# 3                     NaN              NaN                     NaN
# 4                       X                X                       X
# 5                       X                X                     NaN
#
#   must discuss contraception importance of abstinence  \
# 0                          X                   stress
# 1                         na                       na
# 2                        NaN                   stress
# 3                        NaN                   stress
# 4                          X                    cover
# 5                          X                    cover
#
#   Importance of Sex Only Within Marriage Discuss Sexual Orientation  \
# 0                                      X                   negative
# 1                                     na                         na
# 2                                    NaN                        NaN
# 3                                      X                        NaN
# 4                                    NaN                  inclusive
# 5                                    NaN                  inclusive
#
#   Negative Outcomes of Teen Sex Family Communication
# 0                             X                  NaN
# 1                            na                   na
# 2                             X                  NaN
# 3                           NaN                  NaN
# 4                           NaN                    X
# 5                           NaN                    X

# %% [markdown]
# ### Replacing all 'NaN' with 'No' to indicate states do not follow those guideslines

# %%
data.fillna('No', inplace=True)
data.loc[:10,'abortion per 1000 women (aged 15-44)':'Family Communication']
# Out:
#     abortion per 1000 women (aged 15-44)  fraction of abortions under age 19  \
# 0                                      9                                0.13
# 1                                     10                                0.14
# 2                                     10                                0.11
# 3                                     10                                0.12
# 4                                     10                                0.12
# 5                                     10                                0.12
# 6                                     15                                0.12
# 7                                     17                                0.14
# 8                                     15                                0.15
# 9                                     20                                0.12
# 10                                    15                                0.11
#
#    sex ed mandated HIV ed mandated must be medically accurate  \
# 0               No               X                         No
# 1               na              na                         na
# 2               No              No                         No
# 3               No              No                         No
# 4                X               X                          X
# 5               No              No                          X
# 6               No               X                         No
# 7                X               X                         No
# 8                X               X                         No
# 9               No              No                         No
# 10               X               X                         No
#
#    must be age appropriate must be unbiased cannot promote religion  \
# 0                        X               No                      No
# 1                       na               na                      na
# 2                        X               No                      No
# 3                       No               No                      No
# 4                        X                X                       X
# 5                        X                X                      No
# 6                       No               No                      No
# 7                       No               No                      No
# 8                        X               No                      No
# 9                        X               No                      No
# 10                      No               No                      No
#
#    must discuss contraception importance of abstinence  \
# 0                           X                   stress
# 1                          na                       na
# 2                          No                   stress
# 3                          No                   stress
# 4                           X                    cover
# 5                           X                    cover
# 6                          na                       na
# 7                           X                   stress
# 8                           X                       No
# 9                          No                   stress
# 10                         No                   stress
#
#    Importance of Sex Only Within Marriage Discuss Sexual Orientation  \
# 0                                       X                   negative
# 1                                      na                         na
# 2                                      No                         No
# 3                                       X                         No
# 4                                      No                  inclusive
# 5                                      No                  inclusive
# 6                                      na                         na
# 7                                      No                  inclusive
# 8                                      No                         No
# 9                                       X                         No
# 10                                      X                         No
#
#    Negative Outcomes of Teen Sex Family Communication
# 0                              X                   No
# 1                             na                   na
# 2                              X                   No
# 3                             No                   No
# 4                             No                    X
# 5                             No                    X
# 6                             na                   na
# 7                             No                   No
# 8                             No                   No
# 9                              X                   No
# 10                             X                   No

# %% [markdown]
# ### Using a dictionary to map values
# Converting yes/no values to binary, with a few special cases to differentiate levels

# %%
yes_no = {
    'X': 1,
    'No': 0,
    'stress': 2,
    'cover': 1,
    'negative': -1,
    'inclusive': 1
}

for col in data.loc[:5,'sex ed mandated':'Family Communication'].columns:
    data[col] = data[col].map(yes_no)
    
data.loc[:10,'abortion per 1000 women (aged 15-44)':'Family Communication']
# Out:
#     abortion per 1000 women (aged 15-44)  fraction of abortions under age 19  \
# 0                                      9                                0.13
# 1                                     10                                0.14
# 2                                     10                                0.11
# 3                                     10                                0.12
# 4                                     10                                0.12
# 5                                     10                                0.12
# 6                                     15                                0.12
# 7                                     17                                0.14
# 8                                     15                                0.15
# 9                                     20                                0.12
# 10                                    15                                0.11
#
#     sex ed mandated  HIV ed mandated  must be medically accurate  \
# 0               0.0              1.0                         0.0
# 1               NaN              NaN                         NaN
# 2               0.0              0.0                         0.0
# 3               0.0              0.0                         0.0
# 4               1.0              1.0                         1.0
# 5               0.0              0.0                         1.0
# 6               0.0              1.0                         0.0
# 7               1.0              1.0                         0.0
# 8               1.0              1.0                         0.0
# 9               0.0              0.0                         0.0
# 10              1.0              1.0                         0.0
#
#     must be age appropriate  must be unbiased  cannot promote religion  \
# 0                       1.0               0.0                      0.0
# 1                       NaN               NaN                      NaN
# 2                       1.0               0.0                      0.0
# 3                       0.0               0.0                      0.0
# 4                       1.0               1.0                      1.0
# 5                       1.0               1.0                      0.0
# 6                       0.0               0.0                      0.0
# 7                       0.0               0.0                      0.0
# 8                       1.0               0.0                      0.0
# 9                       1.0               0.0                      0.0
# 10                      0.0               0.0                      0.0
#
#     must discuss contraception  importance of abstinence  \
# 0                          1.0                       2.0
# 1                          NaN                       NaN
# 2                          0.0                       2.0
# 3                          0.0                       2.0
# 4                          1.0                       1.0
# 5                          1.0                       1.0
# 6                          NaN                       NaN
# 7                          1.0                       2.0
# 8                          1.0                       0.0
# 9                          0.0                       2.0
# 10                         0.0                       2.0
#
#     Importance of Sex Only Within Marriage  Discuss Sexual Orientation  \
# 0                                      1.0                        -1.0
# 1                                      NaN                         NaN
# 2                                      0.0                         0.0
# 3                                      1.0                         0.0
# 4                                      0.0                         1.0
# 5                                      0.0                         1.0
# 6                                      NaN                         NaN
# 7                                      0.0                         1.0
# 8                                      0.0                         0.0
# 9                                      1.0                         0.0
# 10                                     1.0                         0.0
#
#     Negative Outcomes of Teen Sex  Family Communication
# 0                             1.0                   0.0
# 1                             NaN                   NaN
# 2                             1.0                   0.0
# 3                             0.0                   0.0
# 4                             0.0                   1.0
# 5                             0.0                   1.0
# 6                             NaN                   NaN
# 7                             0.0                   0.0
# 8                             0.0                   0.0
# 9                             1.0                   0.0
# 10                            1.0                   0.0

# %% [markdown]
# ### Replacing any remaining NaN (values that were originally not available) with the average from the column

# %%
data = data.fillna(data.mean()).round(2)
data.loc[:10,'abortion per 1000 women (aged 15-44)':'Family Communication']
# Out:
#     abortion per 1000 women (aged 15-44)  fraction of abortions under age 19  \
# 0                                      9                                0.13
# 1                                     10                                0.14
# 2                                     10                                0.11
# 3                                     10                                0.12
# 4                                     10                                0.12
# 5                                     10                                0.12
# 6                                     15                                0.12
# 7                                     17                                0.14
# 8                                     15                                0.15
# 9                                     20                                0.12
# 10                                    15                                0.11
#
#     sex ed mandated  HIV ed mandated  must be medically accurate  \
# 0              0.00             1.00                        0.00
# 1              0.54             0.76                        0.28
# 2              0.00             0.00                        0.00
# 3              0.00             0.00                        0.00
# 4              1.00             1.00                        1.00
# 5              0.00             0.00                        1.00
# 6              0.00             1.00                        0.00
# 7              1.00             1.00                        0.00
# 8              1.00             1.00                        0.00
# 9              0.00             0.00                        0.00
# 10             1.00             1.00                        0.00
#
#     must be age appropriate  must be unbiased  cannot promote religion  \
# 0                      1.00              0.00                     0.00
# 1                      0.59              0.17                     0.04
# 2                      1.00              0.00                     0.00
# 3                      0.00              0.00                     0.00
# 4                      1.00              1.00                     1.00
# 5                      1.00              1.00                     0.00
# 6                      0.00              0.00                     0.00
# 7                      0.00              0.00                     0.00
# 8                      1.00              0.00                     0.00
# 9                      1.00              0.00                     0.00
# 10                     0.00              0.00                     0.00
#
#     must discuss contraception  importance of abstinence  \
# 0                         1.00                      2.00
# 1                         0.45                      1.48
# 2                         0.00                      2.00
# 3                         0.00                      2.00
# 4                         1.00                      1.00
# 5                         1.00                      1.00
# 6                         0.45                      1.48
# 7                         1.00                      2.00
# 8                         1.00                      0.00
# 9                         0.00                      2.00
# 10                        0.00                      2.00
#
#     Importance of Sex Only Within Marriage  Discuss Sexual Orientation  \
# 0                                     1.00                       -1.00
# 1                                     0.45                        0.19
# 2                                     0.00                        0.00
# 3                                     1.00                        0.00
# 4                                     0.00                        1.00
# 5                                     0.00                        1.00
# 6                                     0.45                        0.19
# 7                                     0.00                        1.00
# 8                                     0.00                        0.00
# 9                                     1.00                        0.00
# 10                                    1.00                        0.00
#
#     Negative Outcomes of Teen Sex  Family Communication
# 0                            1.00                  0.00
# 1                            0.33                  0.24
# 2                            1.00                  0.00
# 3                            0.00                  0.00
# 4                            0.00                  1.00
# 5                            0.00                  1.00
# 6                            0.33                  0.24
# 7                            0.00                  0.00
# 8                            0.00                  0.00
# 9                            1.00                  0.00
# 10                           1.00                  0.00

# %% [markdown]
# ### Removing special characters and converting to float
# All strings containing special symbols like dollar signs, percents, etc. will removed and values converted to float.

# %%
import re

def percent_convert(col):
    for row in data[col]:
        num_str = re.sub('[$%,]', '', str(row))
        num = float(num_str)
        data[col] = data[col].replace(row, num)

# %%
data_num = data.iloc[:,2:]
data_col = data_num.columns
for val in data_col:
    percent_convert(val)

# %% [markdown]
# ### Example of cleaned dataset

# %%
data.head()
# Out:
#         State Code  Teen birth rate (15-19 year olds)  Rel-Very Important  \
# 0     Alabama   AL                               32.0                77.0
# 1      Alaska   AK                               27.8                41.0
# 2     Arizona   AZ                               29.9                51.0
# 3    Arkansas   AR                               39.5                70.0
# 4  California   CA                               21.1                47.0
#
#    Rel-Somewhat Important  Rel-Not too important  Rel-Not at all important  \
# 0                    13.0                    6.0                       4.0
# 1                    29.0                   13.0                      16.0
# 2                    24.0                   13.0                      11.0
# 3                    16.0                    7.0                       5.0
# 4                    26.0                   13.0                      14.0
#
#    Rel-Sample Size  Edu-High School  Edu-Bachelors  ...    \
# 0            511.0             84.3           23.5  ...
# 1            310.0             92.1           28.0  ...
# 2            653.0             86.0           27.5  ...
# 3            311.0             84.8           21.1  ...
# 4           3697.0             81.8           31.4  ...
#
#    must discuss contraception  importance of abstinence  \
# 0                        1.00                      2.00
# 1                        0.45                      1.48
# 2                        0.00                      2.00
# 3                        0.00                      2.00
# 4                        1.00                      1.00
#
#    Importance of Sex Only Within Marriage  Discuss Sexual Orientation  \
# 0                                    1.00                       -1.00
# 1                                    0.45                        0.19
# 2                                    0.00                        0.00
# 3                                    1.00                        0.00
# 4                                    0.00                        1.00
#
#    Negative Outcomes of Teen Sex  Family Communication  White  Black  \
# 0                           1.00                  0.00   0.65   0.27
# 1                           0.33                  0.24   0.58   0.03
# 2                           1.00                  0.00   0.51   0.04
# 3                           0.00                  0.00   0.74   0.15
# 4                           0.00                  1.00   0.39   0.06
#
#    Hispanic  Asian
# 0      0.04   0.04
# 1      0.06   0.07
# 2      0.37   0.03
# 3      0.07   0.02
# 4      0.38   0.15
#
# [5 rows x 46 columns]

# %%
data.describe()
# Out:
#        Teen birth rate (15-19 year olds)  Rel-Very Important  \
# count                          51.000000           51.000000
# mean                           24.496078           52.647059
# std                             7.797588           10.648612
# min                            10.600000           32.000000
# 25%                            19.200000           45.500000
# 50%                            23.200000           51.000000
# 75%                            28.500000           59.500000
# max                            39.500000           77.000000
#
#        Rel-Somewhat Important  Rel-Not too important  \
# count               51.000000              51.000000
# mean                24.352941              11.235294
# std                  4.385538               3.922184
# min                 13.000000               4.000000
# 25%                 22.500000               8.500000
# 50%                 25.000000              12.000000
# 75%                 27.000000              13.000000
# max                 32.000000              23.000000
#
#        Rel-Not at all important  Rel-Sample Size  Edu-High School  \
# count                 51.000000        51.000000        51.000000
# mean                  11.078431       687.666667        87.782353
# std                    4.302758       646.733165         3.657087
# min                    4.000000       301.000000        73.000000
# 25%                    8.000000       312.000000        85.550000
# 50%                   11.000000       439.000000        88.400000
# 75%                   14.000000       709.000000        90.550000
# max                   22.000000      3697.000000        92.800000
#
#        Edu-Bachelors  Edu-Advanced  Clinton vote %    ...      \
# count      51.000000     51.000000       51.000000    ...
# mean       29.639216     11.243137       44.660392    ...
# std         6.028170      3.838919       12.031227    ...
# min        19.200000      7.400000       19.730000    ...
# 25%        26.200000      9.100000       35.900000    ...
# 50%        28.800000     10.400000       45.130000    ...
# 75%        32.100000     12.150000       51.580000    ...
# max        54.600000     31.300000       90.480000    ...
#
#        must discuss contraception  importance of abstinence  \
# count                   51.000000                 51.000000
# mean                     0.451961                  1.476863
# std                      0.456175                  0.639942
# min                      0.000000                  0.000000
# 25%                      0.000000                  1.000000
# 50%                      0.450000                  1.480000
# 75%                      1.000000                  2.000000
# max                      1.000000                  2.000000
#
#        Importance of Sex Only Within Marriage  Discuss Sexual Orientation  \
# count                               51.000000                   51.000000
# mean                                 0.451961                    0.190392
# std                                  0.456175                    0.457738
# min                                  0.000000                   -1.000000
# 25%                                  0.000000                    0.000000
# 50%                                  0.450000                    0.000000
# 75%                                  1.000000                    0.190000
# max                                  1.000000                    1.000000
#
#        Negative Outcomes of Teen Sex  Family Communication      White  \
# count                      51.000000             51.000000  51.000000
# mean                        0.332745              0.238431   0.684314
# std                         0.432051              0.390361   0.164915
# min                         0.000000              0.000000   0.190000
# 25%                         0.000000              0.000000   0.580000
# 50%                         0.000000              0.000000   0.720000
# 75%                         1.000000              0.240000   0.805000
# max                         1.000000              1.000000   0.940000
#
#            Black   Hispanic      Asian
# count  51.000000  51.000000  51.000000
# mean    0.110196   0.118235   0.045490
# std     0.106461   0.099774   0.056083
# min     0.010000   0.010000   0.010000
# 25%     0.030000   0.050000   0.020000
# 50%     0.070000   0.100000   0.030000
# 75%     0.145000   0.140000   0.050000
# max     0.460000   0.440000   0.390000
#
# [8 rows x 44 columns]

# %% [markdown]
# # Plotting all factors vs. teen pregnancy rate to explore correlations

# %%
data_col_plot = data_col[1:]
data_col_plot
# Out:
# Index(['Rel-Very Important', 'Rel-Somewhat Important', 'Rel-Not too important',
#        'Rel-Not at all important', 'Rel-Sample Size', 'Edu-High School',
#        'Edu-Bachelors', 'Edu-Advanced', 'Clinton vote %', 'Trump vote %',
#        'Gary Johnson vote %', 'Jill Stein vote %', 'Obama vote %-12',
#        'Romney vote %-12', 'Gary Johnson vote %-12', 'Jill Stein vote %-12',
#        'Obama vote % 08', 'McCain vote %', 'GDP (millions)', 'Population',
#        'Land Area (sq mi)', '2010 to 2014 change', '2014 spent per student',
#        'Poverty Rate', 'Median Income', 'abortion per 1000 women (aged 15-44)',
#        'fraction of abortions under age 19', 'sex ed mandated',
#        'HIV ed mandated', 'must be medically accurate',
#        'must be age appropriate', 'must be unbiased',
#        'cannot promote religion', 'must discuss contraception',
#        'importance of abstinence', 'Importance of Sex Only Within Marriage',
#        'Discuss Sexual Orientation', 'Negative Outcomes of Teen Sex',
#        'Family Communication', 'White', 'Black', 'Hispanic', 'Asian'],
#       dtype='object')

# %%
from scipy.stats.stats import pearsonr
# %matplotlib inline
fig = plt.figure(figsize=(18, 80))
corr_coeff_p_val = []

for i in range(0,len(data_col_plot)):
    ax = fig.add_subplot(len(data_col_plot)-1/3,3,i+1)
    ax.scatter(data[data_col_plot[i]], data['Teen birth rate (15-19 year olds)'], c='blue')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xlabel(data_col_plot[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
plt.show()

# %% [markdown]
# # Summary of Correlations
# A number of strong correlations do appear, particularly for the continuous variables. For the binary variables from sex education, some trends do appear but are more difficult to visualize. A rough summary of higher correlations:
# - religion importance
# - education level
# - obama/mccain/romney vote levels, though note 2016 election results show little correlation
# - money spent per student on education
# - poverty rate
# - median income
# - abortion rate
# - sex ed that is medically accurate
# - sex ed that must be unbiased
# - sex ed that discusses negative outcomes of teen sex

# %% [markdown]
# # Creating new factors with data—GDP per capita, Population Density, and Teen abortion rate
# A few of our variables can be combined to make more meaningful statistics, such as combined GDP and population to make per capita GDP, combined population and land area for population density, and combined the fraction of teen abortions with the overall abortion rate to get the abortions from teens specifically.

# %%
data['GDP Per Capita'] = data['GDP (millions)'] / data['Population']
data['Population Density'] = data['Population'] / data['Land Area (sq mi)']
data['teen abortions per 1000'] = data['abortion per 1000 women (aged 15-44)'] * data['fraction of abortions under age 19']

fig = plt.figure(figsize=(18,4))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
ax1.scatter(data['GDP Per Capita'], data['Teen birth rate (15-19 year olds)'], c='blue')
ax1.set_xlabel('GDP Per Capita')
ax2.scatter(data['Population Density'], data['Teen birth rate (15-19 year olds)'], c='blue')
ax2.set_xlabel('Population Density')
ax3.scatter(data['teen abortions per 1000'], data['Teen birth rate (15-19 year olds)'], c='blue')
ax3.set_xlabel('teen abortions')

plt.show()

# %% [markdown]
# # Removing Washington DC as an outlier
# Washington DC appears to be a large outlier in the previous plots. It will be removed from the analysis to prevent skewing data, as well as because it's unique in that it is not a state directly.

# %%
no_DC = data.drop([8])
no_DC = no_DC.reset_index(drop=True)
no_DC.head(10)
# Out:
#          State Code  Teen birth rate (15-19 year olds)  Rel-Very Important  \
# 0      Alabama   AL                               32.0                77.0
# 1       Alaska   AK                               27.8                41.0
# 2      Arizona   AZ                               29.9                51.0
# 3     Arkansas   AR                               39.5                70.0
# 4   California   CA                               21.1                47.0
# 5     Colorado   CO                               20.3                47.0
# 6  Connecticut   CT                               11.5                42.0
# 7     Delaware   DE                               20.7                46.0
# 8      Florida   FL                               22.5                53.0
# 9      Georgia   GA                               28.4                64.0
#
#    Rel-Somewhat Important  Rel-Not too important  Rel-Not at all important  \
# 0                    13.0                    6.0                       4.0
# 1                    29.0                   13.0                      16.0
# 2                    24.0                   13.0                      11.0
# 3                    16.0                    7.0                       5.0
# 4                    26.0                   13.0                      14.0
# 5                    28.0                   12.0                      13.0
# 6                    27.0                   17.0                      14.0
# 7                    31.0                   10.0                      11.0
# 8                    25.0                   11.0                      11.0
# 9                    20.0                    7.0                       8.0
#
#    Rel-Sample Size  Edu-High School  Edu-Bachelors           ...             \
# 0            511.0             84.3           23.5           ...
# 1            310.0             92.1           28.0           ...
# 2            653.0             86.0           27.5           ...
# 3            311.0             84.8           21.1           ...
# 4           3697.0             81.8           31.4           ...
# 5            504.0             90.7           38.1           ...
# 6            377.0             89.9           37.6           ...
# 7            301.0             88.4           30.0           ...
# 8           2020.0             86.9           27.3           ...
# 9            968.0             85.4           28.8           ...
#
#    Discuss Sexual Orientation  Negative Outcomes of Teen Sex  \
# 0                       -1.00                           1.00
# 1                        0.19                           0.33
# 2                        0.00                           1.00
# 3                        0.00                           0.00
# 4                        1.00                           0.00
# 5                        1.00                           0.00
# 6                        0.19                           0.33
# 7                        1.00                           0.00
# 8                        0.00                           1.00
# 9                        0.00                           1.00
#
#    Family Communication  White  Black  Hispanic  Asian  GDP Per Capita  \
# 0                  0.00   0.65   0.27      0.04   0.04        0.042860
# 1                  0.24   0.58   0.03      0.06   0.07        0.071404
# 2                  0.00   0.51   0.04      0.37   0.03        0.047395
# 3                  0.00   0.74   0.15      0.07   0.02        0.041390
# 4                  1.00   0.39   0.06      0.38   0.15        0.069863
# 5                  1.00   0.69   0.04      0.21   0.03        0.064363
# 6                  0.24   0.70   0.09      0.15   0.04        0.073691
# 7                  0.00   0.63   0.21      0.10   0.04        0.078388
# 8                  0.00   0.54   0.16      0.26   0.02        0.049295
# 9                  0.00   0.52   0.31      0.10   0.05        0.054230
#
#    Population Density  teen abortions per 1000
# 0           94.193126                     1.17
# 1            1.241768                     1.40
# 2           56.250637                     1.10
# 3           56.001930                     1.20
# 4          238.869669                     1.20
# 5           48.489354                     1.20
# 6          737.718172                     1.80
# 7          459.639837                     2.38
# 8          348.644886                     2.40
# 9          167.299236                     1.65
#
# [10 rows x 49 columns]

# %% [markdown]
# ### GDP per capita and Population Density correlations with Teen pregnancy without Washington DC

# %%
no_DC['GDP Per Capita'] = no_DC['GDP (millions)'] / no_DC['Population']
no_DC['Population Density'] = no_DC['Population']/ no_DC['Land Area (sq mi)']

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2
                     )
ax1.scatter(no_DC['GDP Per Capita'], no_DC['Teen birth rate (15-19 year olds)'], c='blue')
ax1.set_xlabel('GDP Per Capita')
ax2.scatter(no_DC['Population Density'], no_DC['Teen birth rate (15-19 year olds)'], c='blue')
ax2.set_xlabel('Population Density')

plt.show()

# %% [markdown]
# # Filtering out data columns with correlation p-values > 0.05
# Because the data only has 50 samples (50 states), I will need to remove some of the factors to increase the degrees of freedom and prevent over-fitting when performing linear regression. I will remove any variable that does not have a significant correlation with teen pregnancy rate (p-value = 0.05).

# %%
data_corr_coeff = no_DC.iloc[:,3:]
data_corr_coeff_columns = data_corr_coeff.columns

corr_coeff_p_val = [.0001, .0001, .0001]

for i in range(len(data_corr_coeff_columns)):
    corr = pearsonr(data_corr_coeff[data_corr_coeff_columns[i]], no_DC['Teen birth rate (15-19 year olds)'])
    corr_coeff_p_val.append(corr[1])

p_value_tab = pd.DataFrame(no_DC.columns, corr_coeff_p_val)
p_value_tab
# Out:
#                                                    0
# 1.000000e-04                                   State
# 1.000000e-04                                    Code
# 1.000000e-04       Teen birth rate (15-19 year olds)
# 1.240715e-10                      Rel-Very Important
# 3.962906e-05                  Rel-Somewhat Important
# 2.173742e-10                   Rel-Not too important
# 2.417666e-07                Rel-Not at all important
# 6.638894e-01                         Rel-Sample Size
# 2.703974e-02                         Edu-High School
# 1.807235e-08                           Edu-Bachelors
# 8.952574e-06                            Edu-Advanced
# 9.461018e-01                          Clinton vote %
# 7.457569e-01                            Trump vote %
# 6.333029e-01                     Gary Johnson vote %
# 4.283936e-01                       Jill Stein vote %
# 1.161528e-06                         Obama vote %-12
# 9.472451e-07                        Romney vote %-12
# 2.092386e-01                  Gary Johnson vote %-12
# 2.699962e-01                    Jill Stein vote %-12
# 2.789560e-07                         Obama vote % 08
# 1.127425e-07                           McCain vote %
# 4.855166e-01                          GDP (millions)
# 7.828217e-01                              Population
# 6.558308e-02                       Land Area (sq mi)
# 2.301037e-04                     2010 to 2014 change
# 4.502656e-05                  2014 spent per student
# 2.897000e-10                            Poverty Rate
# 3.147556e-06                           Median Income
# 1.317829e-02    abortion per 1000 women (aged 15-44)
# 3.158640e-01      fraction of abortions under age 19
# 8.589356e-01                         sex ed mandated
# 1.332001e-01                         HIV ed mandated
# 1.717251e-02              must be medically accurate
# 7.592072e-01                 must be age appropriate
# 2.481760e-02                        must be unbiased
# 4.375748e-01                 cannot promote religion
# 9.889262e-02              must discuss contraception
# 3.083872e-02                importance of abstinence
# 5.015419e-03  Importance of Sex Only Within Marriage
# 4.228874e-02              Discuss Sexual Orientation
# 6.665770e-03           Negative Outcomes of Teen Sex
# 3.414248e-01                    Family Communication
# 1.603832e-01                                   White
# 6.134196e-02                                   Black
# 5.575508e-01                                Hispanic
# 3.048352e-01                                   Asian
# 3.306316e-05                          GDP Per Capita
# 1.680733e-04                      Population Density
# 3.125089e-02                 teen abortions per 1000

# %%
model_factors = [row < 0.05 for row in corr_coeff_p_val]
data_model = no_DC.loc[:,model_factors]
data_model.iloc[0,3:]
# Out:
# Rel-Very Important                               77
# Rel-Somewhat Important                           13
# Rel-Not too important                             6
# Rel-Not at all important                          4
# Edu-High School                                84.3
# Edu-Bachelors                                  23.5
# Edu-Advanced                                    8.7
# Obama vote %-12                               38.36
# Romney vote %-12                              60.55
# Obama vote % 08                               38.74
# McCain vote %                                 60.32
# 2010 to 2014 change                            -6.4
# 2014 spent per student                         9028
# Poverty Rate                                   19.2
# Median Income                                 44765
# abortion per 1000 women (aged 15-44)              9
# must be medically accurate                        0
# must be unbiased                                  0
# importance of abstinence                          2
# Importance of Sex Only Within Marriage            1
# Discuss Sexual Orientation                       -1
# Negative Outcomes of Teen Sex                     1
# GDP Per Capita                            0.0428603
# Population Density                          94.1931
# teen abortions per 1000                        1.17
# Name: 0, dtype: object

# %% [markdown]
# # Variables with significant correlation to teen pregnancy
# The list above shows all the variables that have significant correlations to teen pregnancy. All of the variables will initially be input into the linear regression model.

# %% [markdown]
# # Running linear regression on significant factors
# The response variable will be the teen pregnancy rate for each state. Each factor will be normalized by dividing by the max value to ensure all variables do not exceed 1.

# %%
from sklearn.linear_model import LinearRegression

Y = data_model.iloc[:,2]
X = data_model.iloc[:,3:]
X_norm = (X / X.max())

mdl = LinearRegression().fit(X_norm,Y) 
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm, Y)
r_squared
# Out:
# 0.9479191504009421

# %% [markdown]
# # Visualizing regression coefficients

# %%
bar_position = range(8)

fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(1,1,1)

ax.bar(range(len(m)), m, 0.5,  color='blue',)

ax.set_xticks(range(len(m)))
ax.set_xticklabels(X.columns, rotation = 90)


plt.ylabel('Correlation Coefficients')
plt.title('Factors affecting teen pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# # Results from initial regression
# The plot of regression coefficients above shows that the model is likely being overfit due to the high number of variables. The R^2 value was 0.95, but a few factors are being amplified, showing over 100% change in teen pregnancy rate. The next model will use regularization to suppress overfitting.

# %% [markdown]
# # Linear regression with regularization

# %%
from sklearn.linear_model import Ridge

Y = data_model.iloc[:,2]
X = data_model.iloc[:,3:]
X_norm = (X / X.max())

clf = Ridge(alpha=1)
mdl = clf.fit(X_norm,Y) 
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm, Y)
r_squared
# Out:
# 0.82096612541339253

# %%
bar_position = range(8)

fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(1,1,1)

ax.bar(range(len(m)), m, 0.5,  color='blue',)

ax.set_xticks(range(len(m)))
ax.set_xticklabels(X.columns, rotation = 90)


plt.ylabel('Correlation Coefficients')
plt.title('Factors affecting teen pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# # Summary of regularized model
# The regularized model shows much more reasonable results with an R^2 of 0.82. All variables contribute smaller percent changes in the pregnancy rate, with religion, education, poverty rate, and population density looking particularly important. Because all of the religion, educational, and political, inputs are related, I will create a single metric for each of these to further reduce the model variables.

# %% [markdown]
# # Reducing model complexity and aggregating related factors
# I will create three combined variables for religion importance, political leanings, and education of the state population, as follows:
# - religion ratio = (very important + somewhat important) / (not too important + not at all important)
# - political ratio = (Obama '12 share + Obama '08 share) / (Romney '12 share + McCain '08 share)
# - education score = 1\*high school educated + 2\*bachelors educated + 3\*advanced degree educated
#
# While these metrics are arbitrary, they do reflect the overall meaning of these factors in the model and should simplify the fit and help determine which are most important in predicting teen pregnancy rate.

# %%
religion_ratio = (data_model['Rel-Very Important']) + (data_model['Rel-Somewhat Important'])/(data_model['Rel-Not too important'] + data_model['Rel-Not at all important'])
political_ratio = (data_model['Obama vote %-12'] + data_model['Obama vote % 08']) / (data_model['Romney vote %-12'] + data_model['McCain vote %'])
education_score = 1*data_model['Edu-High School'] + 2*data_model['Edu-Bachelors'] + 3*data_model['Edu-Advanced']

print(pearsonr(religion_ratio, no_DC['Teen birth rate (15-19 year olds)']))
print(pearsonr(political_ratio, no_DC['Teen birth rate (15-19 year olds)']))
print(pearsonr(education_score, no_DC['Teen birth rate (15-19 year olds)']))
# Out:
# (0.7667384783619603, 8.489500783097854e-11)
# (-0.61239925505011439, 2.2862678584385383e-06)
# (-0.67132897857641682, 9.5028155073303186e-08)

# %% [markdown]
# ### Adding new aggregated factors to dataset and removing old factors

# %%
data_model_red = data_model.drop(['Rel-Very Important', 'Rel-Somewhat Important',
                                  'Rel-Not too important', 'Rel-Not at all important'],1)
data_model_reduce = data_model_red.drop(['Obama vote %-12', 'Obama vote % 08',
                                  'Romney vote %-12', 'McCain vote %'],1)
data_model_reduced = data_model_reduce.drop(['Edu-High School','Edu-Bachelors', 'Edu-Advanced','2010 to 2014 change'],1)

data_model_reduced['religion ratio'] = religion_ratio
data_model_reduced['political ratio'] = political_ratio
data_model_reduced['education score'] = education_score
data_model_reduced.head()
# Out:
#         State Code  Teen birth rate (15-19 year olds)  2014 spent per student  \
# 0     Alabama   AL                               32.0                  9028.0
# 1      Alaska   AK                               27.8                 18416.0
# 2     Arizona   AZ                               29.9                  7528.0
# 3    Arkansas   AR                               39.5                  9616.0
# 4  California   CA                               21.1                  9595.0
#
#    Poverty Rate  Median Income  abortion per 1000 women (aged 15-44)  \
# 0          19.2        44765.0                                     9
# 1          11.4        73355.0                                    10
# 2          18.2        51492.0                                    10
# 3          18.7        41995.0                                    10
# 4          16.4        64500.0                                    10
#
#    must be medically accurate  must be unbiased  importance of abstinence  \
# 0                        0.00              0.00                      2.00
# 1                        0.28              0.17                      1.48
# 2                        0.00              0.00                      2.00
# 3                        0.00              0.00                      2.00
# 4                        1.00              1.00                      1.00
#
#    Importance of Sex Only Within Marriage  Discuss Sexual Orientation  \
# 0                                    1.00                       -1.00
# 1                                    0.45                        0.19
# 2                                    0.00                        0.00
# 3                                    1.00                        0.00
# 4                                    0.00                        1.00
#
#    Negative Outcomes of Teen Sex  GDP Per Capita  Population Density  \
# 0                           1.00        0.042860           94.193126
# 1                           0.33        0.071404            1.241768
# 2                           1.00        0.047395           56.250637
# 3                           0.00        0.041390           56.001930
# 4                           0.00        0.069863          238.869669
#
#    teen abortions per 1000  religion ratio  political ratio  education score
# 0                     1.17       78.300000         0.637875            157.4
# 1                     1.40       42.000000         0.689021            178.4
# 2                     1.10       52.000000         0.836145            171.6
# 3                     1.20       71.333333         0.634923            149.5
# 4                     1.20       47.962963         1.636965            179.4

# %% [markdown]
# # Linear regression on new, reduced model

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.iloc[:,3:]
X_norm = (X / X.max())

mdl = LinearRegression().fit(X_norm,Y) 
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm, Y)
r_squared
# Out:
# 0.88871201468158312

# %%
bar_position = range(8)

fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(1,1,1)

ax.bar(range(len(m)), m, 0.5,  color='blue',)

ax.set_xticks(range(len(m)))
ax.set_xticklabels(X.columns, rotation = 90)


plt.ylabel('Correlation Coefficients')
plt.title('Factors affecting teen pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# # Summary of regression on reduced model
# Regression without regularization shows better results with the aggregated factors. Poverty rate, income, religion ratio, political ratio, and education score look significant. While the coefficient changes on the response are more reasonable than the initial fit without regularization (~30% changes), they are still relatively large. I will re-fit with regularization again.

# %% [markdown]
# # Reduced model fit with regularization

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.iloc[:,3:]
X_norm = (X / X.max())

clf = Ridge(alpha=1)
mdl = clf.fit(X_norm,Y) 
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm, Y)
r_squared
# Out:
# 0.74258879961696367

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(1,1,1)

ax.bar(range(len(m)), m, 0.5,  color='blue',)

ax.set_xticks(range(len(m)))
ax.set_xticklabels(X.columns, rotation = 90)


plt.ylabel('Correlation Coefficients')
plt.title('Factors affecting teen pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# # Reduced, regularized model results
# This model matches well with the previous one in showing that poverty rate and religion ratio are the most dominant factors predicting teen pregnancy. Other important factors appear to be population density, political ratio, and education score. At this point, I will focus my analysis on these 5 factors. Unfortunately the Ridge model doesn't show summary statistics to prove these are the significant factors, so this selection is done be visual inspection.

# %% [markdown]
# # Re-running linear regression with significant factors

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.loc[:,['Poverty Rate','Population Density', 'religion ratio', 
                                  'political ratio','education score']]
X_norm = (X) / X.max()

mdl = LinearRegression().fit(X_norm,Y)
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm,Y)
r_squared
# Out:
# 0.79226688946978163

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1,1,1)

ax.bar(range(len(m)), m, 0.5,  color='blue',)

ax.set_xticks(range(len(m)))
ax.set_xticklabels(X.columns, rotation = 90)


plt.ylabel('Correlation Coefficients')
plt.title('Factors affecting teen pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# # Summary of model results
# The model with the 5 factors above has an R^2 value of 0.79. The unregularized and regularized models with 16 factors had R^2 values of 0.88 and 0.86 respectively. Thus, I have reduced the explanatory variables by 1/3, while still explaining a high fraction of the data variance. Now that the model is fit reasonably without regularization, the model statistics can be viewed.

# %%
import statsmodels.api as sm

X2 = sm.add_constant(X_norm)
est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Teen birth rate (15-19 year olds)   R-squared:                       0.792
# Model:                                           OLS   Adj. R-squared:                  0.769
# Method:                                Least Squares   F-statistic:                     33.56
# Date:                               Wed, 23 Aug 2017   Prob (F-statistic):           5.84e-14
# Time:                                       17:41:07   Log-Likelihood:                -134.22
# No. Observations:                                 50   AIC:                             280.4
# Df Residuals:                                     44   BIC:                             291.9
# Df Model:                                          5
# Covariance Type:                           nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 14.1295      9.332      1.514      0.137      -4.679      32.938
# Poverty Rate          20.0526      5.836      3.436      0.001       8.291      31.815
# Population Density    -7.7083      3.072     -2.509      0.016     -13.900      -1.517
# religion ratio        17.3403      6.786      2.555      0.014       3.664      31.017
# political ratio       -5.2990      4.520     -1.172      0.247     -14.409       3.811
# education score      -14.6874      8.804     -1.668      0.102     -32.431       3.056
# ==============================================================================
# Omnibus:                        3.816   Durbin-Watson:                   2.476
# Prob(Omnibus):                  0.148   Jarque-Bera (JB):                3.046
# Skew:                           0.481   Prob(JB):                        0.218
# Kurtosis:                       2.268   Cond. No.                         39.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/Mark/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Summary statistics
# Interestingly, the education score is not signficant despite having a relatively large coefficient, while the population density is significant with a smaller coefficient. This may be due to multicollinearity between variables.

# %% [markdown]
# # Examining if religion ratio, poverty rate, and population density are linearly independent from education score

# %%
plt.scatter(data_model_reduced['Poverty Rate'], data_model_reduced['education score'])
pearsonr(data_model_reduced['Poverty Rate'], data_model_reduced['education score'])
# Out:
# (-0.51807215989512734, 0.00011643458171600804)

# %%
plt.scatter(data_model_reduced['religion ratio'], data_model_reduced['education score'])
pearsonr(data_model_reduced['religion ratio'], data_model_reduced['education score'])
# Out:
# (-0.54305202350286297, 4.6063214116296615e-05)

# %%
plt.scatter(data_model_reduced['Population Density'], data_model_reduced['education score'])
pearsonr(data_model_reduced['Population Density'], data_model_reduced['education score'])
# Out:
# (0.47029904321442739, 0.00056826550278010768)

# %% [markdown]
# ### Education score is significantly correlated with all three factors that have p-values < 0.05 (religion, poverty, and population density)

# %% [markdown]
# # Exploring correlations between significant factors (religion, poverty, population density)

# %%
plt.scatter(data_model_reduced['Poverty Rate'], data_model_reduced['religion ratio'])
pearsonr(data_model_reduced['Poverty Rate'], data_model_reduced['religion ratio'])
# Out:
# (0.70823572790471356, 8.7607908655004781e-09)

# %%
plt.scatter(data_model_reduced['Poverty Rate'], data_model_reduced['Population Density'])
pearsonr(data_model_reduced['Poverty Rate'], data_model_reduced['Population Density'])
# Out:
# (-0.2574162171769957, 0.07111896316598329)

# %%
plt.scatter(data_model_reduced['religion ratio'], data_model_reduced['Population Density'])
pearsonr(data_model_reduced['religion ratio'], data_model_reduced['Population Density'])
# Out:
# (-0.22531651622191798, 0.11566401628055697)

# %% [markdown]
# # Summary of correlations
# Population density is not correlated significantly with either religion ratio or poverty rate, which is likely the reason it's significant in the model with a smaller coefficient. Religion ratio and poverty rate are correlated, so we will explore a final model by removing each factor, one at a time.

# %% [markdown]
# # Model with religion rate, poverty rate, and population density

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.loc[:,['Population Density', 'religion ratio', 'Poverty Rate']]
X_norm = (X) / X.max()

mdl = LinearRegression().fit(X_norm,Y)
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm,Y)
print('intercept: ', b)
print('regression coefficients: ', m)
print('r^2: ', r_squared)
# Out:
# intercept:  11.8739697828
# regression coefficients:  [ -9.18098003  21.61680195  18.16039087 -16.431701  ]
# r^2:  0.785779237582

# %% [markdown]
# # Dropping religion rate from analysis

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.loc[:,['Population Density', 'Poverty Rate']]
X_norm = (X) / X.max()

mdl = LinearRegression().fit(X_norm,Y)
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm,Y)
print('r^2: ', r_squared)
# Out:
# r^2:  0.672072768102

# %% [markdown]
# # Dropping poverty rate from the analysis

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.loc[:,['Population Density', 'religion ratio']]
X_norm = (X) / X.max()

mdl = LinearRegression().fit(X_norm,Y)
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm,Y)
print('r^2: ', r_squared)
# Out:
# r^2:  0.706016185779

# %% [markdown]
# # Dropping population density from the analysis

# %%
Y = data_model_reduced.iloc[:,2]
X = data_model_reduced.loc[:,['Poverty Rate', 'religion ratio']]
X_norm = (X) / X.max()

mdl = LinearRegression().fit(X_norm,Y)
m = mdl.coef_
b = mdl.intercept_
r_squared = mdl.score(X_norm,Y)
print('r^2: ', r_squared)
# Out:
# r^2:  0.676101304971

# %% [markdown]
# # Summary of removing final variables
# Removing any one of the final 3 variables drops the R^2 fit by at least 0.07, meaning each of these is likely playing a signficant role in predicting teen pregnancy. By including religion ratio, poverty rate, and population density, the model achieves a 0.77 fit.

# %% [markdown]
# # Plot of final correlation coefficients to predict teen pregnancy.

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1,1,1)

plot_m = [-4.37, -11.34, 24.779, 20.11]
m_labels = ['Intercept','Population Density', 'Religion Ratio', 'Poverty Rate']

ax.bar(range(len(plot_m)), plot_m, 0.5,  color='blue',)

ax.set_ylim(-20, 30)
plt.ylabel('Max % Change in Teen Pregnancy')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')

ax.axhline(0, c=(171/255, 171/255, 171/255), alpha=0.5)

ax.text(-.27, -7.8, 'Intercept')
ax.text(0.47, -15, 'Population Density')
ax.text(1.6, 27.3, 'Religion Ratio')
ax.text(2.62, 22.5, 'Poverty Rate')

fig.savefig("teen pregnancy rate.pdf")
plt.show()

# %% [markdown]
# # Model Findings in order of importance
# - Religion: teen pregnancy rate goes UP as religiosity goes UP in the state and is the most significant predictor of teen pregnancy rate.
# - Poverty: teen preganancy goes UP as poverty rate goes UP and is second most significant predictor.
# - Population Density: teen pregnancy rate goes DOWN as population density goes UP. The effect of population density is roughly 1/3 of the relgion effect.

# %%
data_model_reduced['religion rank'] = data_model_reduced['religion ratio'].rank(ascending=False).astype(int)
data_model_reduced['density rank'] = data_model_reduced['Population Density'].rank(ascending=False).astype(int)
data_model_reduced['pregnancy rank'] = data_model_reduced['Teen birth rate (15-19 year olds)'].rank(ascending=False).astype(int)
data_model_reduced['poverty rank'] = data_model_reduced['Poverty Rate'].rank(ascending=False).astype(int)
data_model_reduced.iloc[:5,-4:]
# Out:
#    religion rank  density rank  pregnancy rank  poverty rank
# 0              1            27              10             4
# 1             46            50              17            43
# 2             25            33              12             9
# 3              5            34               1             6
# 4             35            11              30            16

# %%
import plotly.plotly as py
import plotly 

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

scl = [[0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data_model_reduced['text'] = 'Pregnancy Rate Rank #' + data_model_reduced['pregnancy rank'].astype(str)+ '<br>' + '<br>'+\
    'Religion Rank #'+ data_model_reduced['religion rank'].astype(str) + '<br>'+\
    'Poverty Rate Rank #'+ data_model_reduced['poverty rank'].astype(str) + '<br>'+\
    'Population Density Rank #'+ data_model_reduced['density rank'].astype(str) 

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = data_model_reduced.iloc[:,2],
        locationmode = 'USA-states',
        text = data_model_reduced['text'],
        hoverinfo = 'skip+text',
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Teen Pregnancy Rate (%)"
        )
    ) ]

layout = dict(
        title = 'Teen Pregnancy by State',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict( data=data, layout=layout )

url = py.plot(fig, filename='teen pregnancy' )
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-43-692e9b26dee8> in <module>()
#      40 fig = dict( data=data, layout=layout )
#      41
# ---> 42 url = py.plot(fig, filename='teen pregnancy' )
#
# /Users/Mark/anaconda/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     226     data = fig.get('data', [])
#     227     plot_options['layout'] = fig.get('layout', {})
# --> 228     response = v1.clientresp(data, **plot_options)
#     229
#     230     # Check if the url needs a secret key
#
# /Users/Mark/anaconda/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /Users/Mark/anaconda/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /Users/Mark/anaconda/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hi there, you've reached the threshold of 100 combined image exports and chart saves per day. If you need to raise your daily limit, consider upgrading to a Student or Personal Plan (see: https://plot.ly/products/cloud).

# %%
scl = [[0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data_model_reduced['text'] = 'Pregnancy Rate Rank #' + data_model_reduced['pregnancy rank'].astype(str)+ '<br>' + '<br>'+\
    'Religion Rank #'+ data_model_reduced['religion rank'].astype(str) + '<br>'+\
    'Poverty Rate Rank #'+ data_model_reduced['poverty rank'].astype(str) + '<br>'+\
    'Population Density Rank #'+ data_model_reduced['density rank'].astype(str) 
    
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = data_model_reduced.loc[:,'religion ratio'],
        locationmode = 'USA-states',
        text = data_model_reduced['text'],
        hoverinfo = 'skip+text',
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Religion Score"
        )
    ) ]

layout = dict(
        title = 'Religiosity by State',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict( data=data, layout=layout )

url = py.plot( fig, filename='teen-pregnancy-rate-map' )

# %%
import plotly.plotly as py
import plotly 

scl = [[0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data_model_reduced['text'] = 'Pregnancy Rate Rank #' + data_model_reduced['pregnancy rank'].astype(str)+ '<br>' + '<br>'+\
    'Religion Rank #'+ data_model_reduced['religion rank'].astype(str) + '<br>'+\
    'Poverty Rate Rank #'+ data_model_reduced['poverty rank'].astype(str) + '<br>'+\
    'Population Density Rank #'+ data_model_reduced['density rank'].astype(str) 

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = data_model_reduced.loc[:,'Population Density'],
        locationmode = 'USA-states',
        text = data_model_reduced['text'],
        hoverinfo = 'skip+text',
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Population Density"
        )
    ) ]

layout = dict(
        title = 'Population Density by State',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict( data=data, layout=layout )

url = py.plot( fig, filename='population density' )

# %%
import plotly.plotly as py
import plotly 

scl = [[0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data_model_reduced['text'] = 'Pregnancy Rate Rank #' + data_model_reduced['pregnancy rank'].astype(str)+ '<br>' + '<br>'+\
    'Religion Rank #'+ data_model_reduced['religion rank'].astype(str) + '<br>'+\
    'Poverty Rate Rank #'+ data_model_reduced['poverty rank'].astype(str) + '<br>'+\
    'Population Density Rank #'+ data_model_reduced['density rank'].astype(str) 

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = data_model_reduced.loc[:,'Poverty Rate'],
        locationmode = 'USA-states',
        text = data_model_reduced['text'],
        hoverinfo = 'skip+text',
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Poverty Rate (%)"
        )
    ) ]

layout = dict(
        title = 'Poverty Rate by State',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict( data=data, layout=layout )

url = py.plot( fig, filename='povert rate' )
